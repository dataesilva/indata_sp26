# %%
my_var = 35

# %%
my_var + 12
# Out:
# 47

# %%
def give_name():
    my_var + 24
    print("David")

# give_name()

# %%
def return_david():
    return "David"

name = return_david()

# %%
def return_elle():
    return "Elle's"

# %%
name = return_elle()
name
# Out:
# "Elle's"

# %%
for i in [1, 2, 3]:
    print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### List Comprehension

# %%
[print(i) for i in [1,2, 3]]
# Out:
# 1
# 2
# 3
# [None, None, None]

# %% [markdown]
# !['A Street Triple Bike'](https://upload.wikimedia.org/wikipedia/commons/thumb/4/49/2014_Triumph_Street_Triple_R_matte_graphite_right_2.JPG/2560px-2014_Triumph_Street_Triple_R_matte_graphite_right_2.JPG)

# %%
import pandas as pd

# %%
data_dict = {'a': [1,2,3], 'b':[4,5,6]}
data_list = [{'a': 1, 'b': 4}, {'a': 2, 'b': 5}, {'a': 3, 'b': 6}]

dat = pd.DataFrame(data_dict)
dat

# %%
dat2 = pd.DataFrame(data_list)
dat2
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
dat.head(1)
# Out:
#    a  b
# 0  1  4

# %%
dat.tail(1)
# Out:
#    a  b
# 2  3  6

# %%
dat['a']
# Out:
# 0    1
# 1    2
# 2    3
# Name: a, dtype: int64

# %%
dat.loc[0]
# Out:
# a    1
# b    4
# Name: 0, dtype: int64

# %%
dat.iloc[0]
# Out:
# a    1
# b    4
# Name: 0, dtype: int64

# %%
dat.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
len(dat.index)
# Out:
# 3

# %%
len(dat.columns)
# Out:
# 2

# %%
dat[['a','b']]
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
dat[dat['a'] > 2]
# Out:
#    a  b
# 2  3  6

# %%
dat[dat['a'] > 2]['a']
# Out:
# 2    3
# Name: a, dtype: int64

# %%
dat.write_csv()
