# %%
3+4
# Out:
# 7

# %%
def my_name():
    print("David")
    return "David"

my_name()
name = my_name()
name
# Out:
# David
# David
# 'David'

# %%
for i in [1,2,3]:
    print(i)
# Out:
# 1
# 2
# 3
