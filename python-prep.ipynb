# %% [markdown]
# ### Basic Python Syntax

# %%
3+4
# Out:
# 7

# %%
def my_name():
    print("David")

def give_name():
    return "David"

my_name()
name = give_name()
name
# Out:
# David
# 'David'

# %%
for i in [1,2,3]:
    print(i)
# Out:
# 1
# 2
# 3
