# %% [markdown]
# # Systems Check
# ### David E. Silva
# ##### EMAT 62110
#
# Making a list
# - thing one
# 1. Thing one
#
# _italics_ __bold__

# %%
my_name = "David"
my_name
# Out:
# 'David'

# %%
def print_name():
    print("David")

print_name()
# Out:
# David

# %%
def give_name():
    return my_name

# %%
new_name = give_name()
new_name
# Out:
# 'David'
